# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 200)

# %%
df_application_train = pd.read_csv("../data/application_train.csv")
# df_application_test = pd.read_csv("../data/application_test.csv")
df_bureau = pd.read_csv("../data/bureau.csv")
df_bureau_balance = pd.read_csv("../data/bureau_balance.csv")
df_previous_application = pd.read_csv("../data/previous_application.csv")
df_installments_payments = pd.read_csv("../data/installments_payments.csv")
df_pos_cash_balance = pd.read_csv("../data/POS_CASH_balance.csv")
df_credit_card_balance = pd.read_csv("../data/credit_card_balance.csv")
df_sample_submission = pd.read_csv("../data/sample_submission.csv")
# df_columns_description = pd.read_csv("../data/HomeCredit_columns_description.csv")

# %%
print(df_application_train.columns.tolist())
df_application_train.head().T
# Out:
# ['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'E
# ...

# %%
print(df_bureau.columns.tolist())
df_bureau.head().T
# Out:
# ['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY', 'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE', 'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG', 'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT', 'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE', 'AMT_ANNUITY']
#                                       0            1                2  \
# SK_ID_CURR                       215354       215354           215354
# SK_ID_BUREAU                    5714462      5714463          5714464
# CREDIT_ACTIVE                    Closed       Active           Active
# CREDIT_CURRENCY              currency 1   currency 1       currency 1
# DAYS_CREDIT                        -497         -208             -203
# CREDIT_DAY_OVERDUE                    0            0                0
# DAYS_CREDIT_ENDDATE              -153.0       1075.0            528.0
# DAYS_ENDDATE_FACT                -153.0          NaN              NaN
# ...

# %%
print(df_bureau_balance.columns.tolist())
df_bureau_balance.head().T
# Out:
# ['SK_ID_BUREAU', 'MONTHS_BALANCE', 'STATUS']
#                       0        1        2        3        4
# SK_ID_BUREAU    5715448  5715448  5715448  5715448  5715448
# MONTHS_BALANCE        0       -1       -2       -3       -4
# STATUS                C        C        C        C        C

# %%
print(df_previous_application.columns.tolist())
df_previous_application.head().T
# Out:
# ['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE', 'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY', 'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'DAYS_DECISION', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY', 'CNT_PAYMENT', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL']
#                                                     0                 1  \
# SK_ID_PREV                                    2030495           2802425
# ...

# %%
print(df_installments_payments.columns.tolist())
df_installments_payments.head().T
# Out:
# ['SK_ID_PREV', 'SK_ID_CURR', 'NUM_INSTALMENT_VERSION', 'NUM_INSTALMENT_NUMBER', 'DAYS_INSTALMENT', 'DAYS_ENTRY_PAYMENT', 'AMT_INSTALMENT', 'AMT_PAYMENT']
#                                  0            1          2           3  \
# SK_ID_PREV              1054186.00  1330831.000  2085231.0  2452527.00
# SK_ID_CURR               161674.00   151639.000   193053.0   199697.00
# NUM_INSTALMENT_VERSION        1.00        0.000        2.0        1.00
# NUM_INSTALMENT_NUMBER         6.00       34.000        1.0        3.00
# DAYS_INSTALMENT           -1180.00    -2156.000      -63.0    -2418.00
# DAYS_ENTRY_PAYMENT        -1187.00    -2156.000      -63.0    -2426.00
# AMT_INSTALMENT             6948.36     1716.525    25425.0    24350.13
# AMT_PAYMENT                6948.36     1716.525    25425.0    24350.13
#
#                                   4
# SK_ID_PREV              2714724.000
# SK_ID_CURR               167756.000
# NUM_INSTALMENT_VERSION        1.000
# ...

# %%
print(df_pos_cash_balance.columns.tolist())
df_pos_cash_balance.head().T
# Out:
# ['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'CNT_INSTALMENT', 'CNT_INSTALMENT_FUTURE', 'NAME_CONTRACT_STATUS', 'SK_DPD', 'SK_DPD_DEF']
#                              0        1        2        3        4
# SK_ID_PREV             1803195  1715348  1784872  1903291  2341044
# SK_ID_CURR              182943   367990   397406   269225   334279
# MONTHS_BALANCE             -31      -33      -32      -35      -35
# CNT_INSTALMENT            48.0     36.0     12.0     48.0     36.0
# CNT_INSTALMENT_FUTURE     45.0     35.0      9.0     42.0     35.0
# NAME_CONTRACT_STATUS    Active   Active   Active   Active   Active
# SK_DPD                       0        0        0        0        0
# SK_DPD_DEF                   0        0        0        0        0

# %%
print(df_credit_card_balance.columns.tolist())
df_credit_card_balance.head().T
# Out:
# ['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE', 'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT', 'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT', 'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY', 'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT', 'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE', 'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT', 'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT', 'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS', 'SK_DPD', 'SK_DPD_DEF']
#                                    0          1          2           3  \
# SK_ID_PREV                   2562384    2582071    1740877     1389973
# SK_ID_CURR                    378907     363914     371185      337855
# MONTHS_BALANCE                    -6         -1         -7          -4
# AMT_BALANCE                    56.97  63975.555  31815.225   236572.11
# AMT_CREDIT_LIMIT_ACTUAL       135000      45000     450000      225000
# ...

# %%
print(df_sample_submission.columns.tolist())
df_sample_submission.head().T
# Out:
# ['SK_ID_CURR', 'TARGET']
#                    0         1         2         3         4
# SK_ID_CURR  100001.0  100005.0  100013.0  100028.0  100038.0
# TARGET           0.5       0.5       0.5       0.5       0.5
